# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
admissions_predict_df = pd.read_csv('/Users/amandine/Desktop/Ironhack/03_Week/lab-advanced-pandas/your-code/data/Admission_Predict.csv') #You can give an argument to read a particular table of the spread sheet
admissions_predict_df.head(3)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# Check for trailing spaces in column names
for column in admissions_predict_df.columns:
    if column.endswith(' '):
        print(f"Column name {column} has trailing spaces.")
# Out:
# Column name LOR  has trailing spaces.
# Column name Chance of Admit  has trailing spaces.

# %%
# With list comprehensions
columns_with_trailing_spaces = [column for column in admissions_predict_df.columns if column.endswith(' ')]
print(f"Columns with trailing spaces: {columns_with_trailing_spaces}")
# Out:
# Columns with trailing spaces: ['LOR ', 'Chance of Admit ']

# %%
# your code here
admissions_predict_df.columns = admissions_predict_df.columns.str.rstrip()
admissions_predict_df.head(3)

#method with list comprehensions : 
#df.columns = [col.strip() for col in df.columns]
#.columns.str.rstrip(): Removes trailing spaces from all column names in the DataFrame, 
#modifying the original DataFrame's column names.
#
#col.strip(): Removes trailing spaces from an individual column name (string) when used within a loop, 
#but it doesn't modify the original DataFrame.
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
#
#    Research  Chance of Admit  CGPA_std   GRE_std
# 0         1             0.92  1.750174  1.755663
# 1         1             0.72 -0.992501 -0.063450
# 2         1             0.80  0.121191  0.456297

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
admissions_predict_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
missing_data = admissions_predict_df.isnull().sum()
print(missing_data)

# Display columns with missing data / other method
#columns_with_missing_data = missing_data[missing_data > 0]
#print(columns_with_missing_data)
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
#admissions_predict_df.set_index(['Serial No.', 'GRE Score', 'CGPA'], inplace=True)
#admissions_predict_df.head()

admissions_predict_df = admissions_predict_df.set_index('Serial No.')
admissions_predict_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here

#admissions_predict_df.set_index(['GRE Score', 'CGPA'], inplace=True)
#admissions_predict_df.head()

admissions_predict_df.set_index(['GRE Score', 'CGPA'], inplace=True, drop=False)
admissions_predict_df.head()
# Out:
#                 GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# GRE Score CGPA
# 337       9.65        337          118                  4  4.5  4.5  9.65
# 316       8.00        316          104                  3  3.0  3.5  8.00
# 322       8.67        322          110                  3  3.5  2.5  8.67
# 314       8.21        314          103                  2  2.0  3.0  8.21
# 330       9.34        330          115                  5  4.5  3.0  9.34
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1             0.92
# 316       8.00         1             0.72
# 322       8.67         1             0.80
# 314       8.21         0             0.65
# 330       9.34         1             0.90

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
admissions_predict_df.set_index(['GRE Score', 'CGPA'], inplace=True, drop=True)
admissions_predict_df.head()
# Out:
#                 TOEFL Score  University Rating  SOP  LOR  Research  \
# GRE Score CGPA
# 337       9.65          118                  4  4.5  4.5         1
# 316       8.00          104                  3  3.0  3.5         1
# 322       8.67          110                  3  3.5  2.5         1
# 314       8.21          103                  2  2.0  3.0         0
# 330       9.34          115                  5  4.5  3.0         1
#
#                 Chance of Admit
# GRE Score CGPA
# 337       9.65             0.92
# 316       8.00             0.72
# 322       8.67             0.80
# 314       8.21             0.65
# 330       9.34             0.90

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
admissions_predict_df.reset_index(inplace=True)
admissions_predict_df.head()
# Out:
#    index  GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0      0        337  9.65          118                  4  4.5  4.5         1
# 1      1        316  8.00          104                  3  3.0  3.5         1
# 2      2        322  8.67          110                  3  3.5  2.5         1
# 3      3        314  8.21          103                  2  2.0  3.0         0
# 4      4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std
# 0             0.92  1.750174  1.755663
# 1             0.72 -0.992501 -0.063450
# 2             0.80  0.121191  0.456297
# 3             0.65 -0.643433 -0.236698
# 4             0.90  1.234884  1.149292

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here
filtered_df = admissions_predict_df[(admissions_predict_df['CGPA'] > 9) & (admissions_predict_df['Research'] == 1)]
filtered_df.head(10)
# Out:
#     GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0         337  9.65          118                  4  4.5  4.5         1
# 4         330  9.34          115                  5  4.5  3.0         1
# 10        328  9.10          112                  4  4.0  4.5         1
# 19        328  9.50          116                  5  5.0  5.0         1
# 20        334  9.70          119                  5  5.0  4.5         1
# 21        336  9.80          119                  5  4.0  3.5         1
# 28        338  9.40          118                  4  3.0  4.5         1
# 29        340  9.60          114                  5  4.0  4.0         1
# 30        331  9.80          112                  5  4.0  5.0         1
# 31        320  9.20          110                  5  5.0  5.0         1
#
#     Chance of Admit
# 0              0.92
# 4              0.90
# 10             0.78
# 19             0.94
# 20             0.95
# 21             0.97
# 28             0.91
# 29             0.90
# 30             0.94
# 31             0.88

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
sop_score = filtered_df[(filtered_df['SOP'] < 3.5)]
sop_score.head(10)
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 28         338  9.40          118                  4  3.0  4.5         1
# 140        326  9.11          114                  3  3.0  3.0         1
# 217        324  9.01          111                  4  3.0  3.0         1
# 381        325  9.11          107                  3  3.0  3.5         1
#
#      Chance of Admit
# 28              0.91
# 140             0.83
# 217             0.82
# 381             0.84

# %%
mean_chance_of_admit = sop_score['Chance of Admit'].mean()
print(f"Mean Chance of Admit for these applicants: {mean_chance_of_admit:.2f}")
# Out:
# Mean Chance of Admit for these applicants: 0.85

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(column):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    mean = np.mean(column)
    std_dev = np.std(column)
    standardized_column = (column - mean) / std_dev
    return standardized_column

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here

# Create the standardized columns
admissions_predict_df['CGPA_std'] = standardize(admissions_predict_df['CGPA'])
admissions_predict_df['GRE_std'] = standardize(admissions_predict_df['GRE Score'])
admissions_predict_df['LOR_std'] = standardize(admissions_predict_df['LOR']) #important to remove the trailing spaces before
#otherwise it leads to error

# Display the DataFrame with the new columns
admissions_predict_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0         1             0.92  1.750174  1.755663  1.193197
# 1         1             0.72 -0.992501 -0.063450  0.076840
# 2         1             0.80  0.121191  0.456297 -1.039517
# 3         0             0.65 -0.643433 -0.236698 -0.481338
# 4         1             0.90  1.234884  1.149292 -0.481338

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
#std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

#decision_choice = choices(std_columns, k=admissions.shape[0])

std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']
decision_choice = choices(std_columns, k=admissions_predict_df.shape[0])
print(decision_choice)
# Out:
# ['CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'LOR_std', 'GRE_std', 'GRE_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'CGPA_std', 'LOR_std', 'CGPA_std', 'GRE_std', 'CGPA_std', 'LOR_std', 'GRE_std', 'GRE_std', 'GRE_std', 'LOR_std', 'GRE_std', 'CGPA_std', 'GRE_std', 'GRE_std', 'LOR_std', 'CGPA_s ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
admissions_predict_df['deciding_column'] = decision_choice
admissions_predict_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std deciding_column
# 0         1             0.92  1.750174  1.755663  1.193197        CGPA_std
# 1         1             0.72 -0.992501 -0.063450  0.076840        CGPA_std
# 2         1             0.80  0.121191  0.456297 -1.039517         LOR_std
# 3         0             0.65 -0.643433 -0.236698 -0.481338        CGPA_std
# 4         1             0.90  1.234884  1.149292 -0.481338         LOR_std

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
# Create a mask for each condition
mask = (admissions_predict_df['deciding_column'] > 0.8)

# Create the 'decision' column
admissions_predict_df['decision'] = np.where(mask, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[274], line 3
#       1 # your code here
#       2 # Create a mask for each condition
# ----> 3 mask = (admissions_predict_df['deciding_column'] > 0.8)
#       5 # Create the 'decision' column
#       6 admissions_predict_df['decision'] = np.where(mask, 1, 0)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
